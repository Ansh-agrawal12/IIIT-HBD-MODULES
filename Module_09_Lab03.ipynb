# %% [markdown]
# <a href="https://colab.research.google.com/github/Ansh-agrawal12/IIIT-HBD-MODULES/blob/main/Module_09_Lab03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Module 9: Neural Networks
#
# Lab 2: Using MLP for multiclass classification

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load the iris dataset
iris = load_iris()
X = iris['data']
y = iris['target']
names = iris['target_names']
feature_names = iris['feature_names']

# Scale data to have mean 0 and variance 1
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data set into training and testing
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=2)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
for target, target_name in enumerate(names):
    X_plot = X[y == target]
    ax1.plot(X_plot[:, 0], X_plot[:, 1],
             linestyle='none',
             marker='o',
             label=target_name)
ax1.set_xlabel(feature_names[0])
ax1.set_ylabel(feature_names[1])
ax1.axis('equal')
ax1.legend();

for target, target_name in enumerate(names):
    X_plot = X[y == target]
    ax2.plot(X_plot[:, 2], X_plot[:, 3],
             linestyle='none',
             marker='o',
             label=target_name)
ax2.set_xlabel(feature_names[2])
ax2.set_ylabel(feature_names[3])
ax2.axis('equal')
ax2.legend();

# %% [markdown]
# MLP for multiclass classification

# %%
import torch
import torch.nn.functional as F
import torch.nn as nn
from torch.autograd import Variable
import tqdm

# %%
# Defining the model architecture
class Model(nn.Module):
    def __init__(self, input_dim):
        super(Model, self).__init__()
        self.layer1 = nn.Linear(input_dim, 50)
        self.layer2 = nn.Linear(50, 50)
        self.layer3 = nn.Linear(50, 3)

    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        x = F.softmax(self.layer3(x), dim=1)
        return x

# %%
# Instantiating the model, using Adam optimiser, and Cross Entropy Loss, which is quite commonlu used for classification tasks.
model     = Model(X_train.shape[1])
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_fn   = nn.CrossEntropyLoss()

# %% [markdown]
# Train the model

# %%
# Train for 100 epochs
EPOCHS  = 100
X_train = torch.from_numpy(X_train).float()
X_test= torch.from_numpy(X_test).float()
y_test = torch.from_numpy(y_test)
y_train = torch.from_numpy(y_train)


loss_list     = np.zeros((EPOCHS,))
accuracy_list = np.zeros((EPOCHS,))

for epoch in tqdm.trange(EPOCHS):
    y_pred = model(X_train)
    loss = loss_fn(y_pred, y_train)
    loss_list[epoch] = loss.item()

    # Zero gradients
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    with torch.no_grad():
        y_pred = model(X_test)
        correct = (torch.argmax(y_pred, dim=1) == y_test).type(torch.FloatTensor)
        accuracy_list[epoch] = correct.mean()
# Out:
# 100%|██████████| 100/100 [00:02<00:00, 48.86it/s]

# %% [markdown]
# Plot training progress

# %%
fig, (ax1, ax2) = plt.subplots(2, figsize=(12, 6), sharex=True)

ax1.plot(accuracy_list)
ax1.set_ylabel("validation accuracy")
ax2.plot(loss_list)
ax2.set_ylabel("validation loss")
ax2.set_xlabel("epochs");

# %% [markdown]
# Experiment with the neural network architecture
#
# 1)Try changing the number of hidden layers.
#
# 2)Try changing the number of neurons in the hidden layer.
#
# 3)Try using a different activation function.
# Can you observe any changes?

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, activations
from tensorflow.keras.datasets import mnist

# Load and preprocess the data
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0

# Base Model
def create_base_model():
    model = models.Sequential([
        layers.Flatten(input_shape=(28, 28)),
        layers.Dense(128, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])
    return model

# Experiment 1: Change the number of hidden layers
def create_model_exp1(num_hidden_layers):
    model = models.Sequential()
    model.add(layers.Flatten(input_shape=(28, 28)))
    for _ in range(num_hidden_layers):
        model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dense(10, activation='softmax'))
    return model

# Experiment 2: Change the number of neurons in the hidden layer
def create_model_exp2(num_neurons):
    model = models.Sequential([
        layers.Flatten(input_shape=(28, 28)),
        layers.Dense(num_neurons, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])
    return model

# Experiment 3: Use a different activation function
def create_model_exp3(activation_func):
    model = models.Sequential([
        layers.Flatten(input_shape=(28, 28)),
        layers.Dense(128, activation=activation_func),
        layers.Dense(10, activation='softmax')
    ])
    return model

# Train and evaluate a given model
def train_and_evaluate(model):
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    model.fit(train_images, train_labels, epochs=5, validation_data=(test_images, test_labels))

# Base Model
print("Base Model:")
base_model = create_base_model()
train_and_evaluate(base_model)

# Experiment 1: Change the number of hidden layers
print("\nExperiment 1: Change the number of hidden layers")
for num_hidden_layers in [1, 2, 3]:
    print(f"\nNumber of hidden layers: {num_hidden_layers}")
    model_exp1 = create_model_exp1(num_hidden_layers)
    train_and_evaluate(model_exp1)

# Experiment 2: Change the number of neurons in the hidden layer
print("\nExperiment 2: Change the number of neurons in the hidden layer")
for num_neurons in [64, 128, 256]:
    print(f"\nNumber of neurons in the hidden layer: {num_neurons}")
    model_exp2 = create_model_exp2(num_neurons)
    train_and_evaluate(model_exp2)

# Experiment 3: Use a different activation function
print("\nExperiment 3: Use a different activation function")
activation_functions = ['relu', 'tanh', 'sigmoid']
for activation_func in activation_functions:
    print(f"\nActivation function: {activation_func}")
    model_exp3 = create_model_exp3(activation_func)
    train_and_evaluate(model_exp3)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Base Model:
# Epoch 1/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2599 - accuracy: 0.9256 - val_loss: 0.1313 - val_accuracy: 0.9603
# Epoch 2/5
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.1148 - accuracy: 0.9661 - val_loss: 0.0997 - val_accuracy: 0.9708
# Epoch 3/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0785 - accuracy: 0.9761 - val_loss: 0.0847 - val_accuracy: 0.9755
# Epoch 4/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0585 - accuracy: 0.9824 - val_loss: 0.0760 - val_accuracy: 0.9765
# Epoch 5/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0451 - accuracy: 0.9857 - val_loss: 0.0711 - val_accuracy: 0.9794
#
# Experiment 1: Change the number of hidden layers
#
# Number of hidden layers: 1
# Epoch 1/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2588 - accuracy: 0.9264 - val_loss: 0.1313 - val_accuracy: 0.9629
# Epoch 2/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1115 - accuracy: 0.9668 - val_loss: 0.0983 - val_accuracy: 0.9682
# Epoch 3/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0780 - accuracy: 0.9765 - val_loss: 0.0917 - val_accuracy: 0.9704
# Epoch 4/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0574 - accuracy: 0.9824 - val_loss: 0.0934 - val_accuracy: 0.9722
# Epoch 5/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0457 - accuracy: 0.9855 - val_loss: 0.0736 - val_accuracy: 0.9785
#
# Number of hidden layers: 2
# Epoch 1/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2313 - accuracy: 0.9324 - val_loss: 0.1064 - val_accuracy: 0.9670
# Epoch 2/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0959 - accuracy: 0.9708 - val_loss: 0.1046 - val_accuracy: 0.9678
# Epoch 3/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0693 - accuracy: 0.9782 - val_loss: 0.0730 - val_accuracy: 0.9779
# Epoch 4/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0510 - accuracy: 0.9838 - val_loss: 0.0849 - val_accuracy: 0.9759
# Epoch 5/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0410 - accuracy: 0.9863 - val_loss: 0.0691 - val_accuracy: 0.9783
#
# Number of hidden layers: 3
# Epoch 1/5
# 1875/1875 [==============================] - 13s 6ms/step - loss: 0.2315 - accuracy: 0.9311 - val_loss: 0.1168 - val_accuracy: 0.9627
# Epoch 2/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1021 - accuracy: 0.9679 - val_loss: 0.0957 - val_accuracy: 0.9697
# Epoch 3/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0732 - accuracy: 0.9774 - val_loss: 0.0940 - val_accuracy: 0.9719
# Epoch 4/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0579 - accuracy: 0.9819 - val_loss: 0.0942 - val_accuracy: 0.9725
# Epoch 5/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0477 - accuracy: 0.9849 - val_loss: 0.0762 - val_accuracy: 0.9782
#
# Experiment 2: Change the number of neurons in the hidden layer
#
# Number of neurons in the hidden layer: 64
# Epoch 1/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2983 - accuracy: 0.9142 - val_loss: 0.1728 - val_accuracy: 0.9478
# Epoch 2/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1466 - accuracy: 0.9571 - val_loss: 0.1224 - val_accuracy: 0.9613
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1078 - accuracy: 0.9680 - val_loss: 0.1100 - val_accuracy: 0.9661
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0857 - accuracy: 0.9748 - val_loss: 0.0921 - val_accuracy: 0.9712
# Epoch 5/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.0707 - accuracy: 0.9786 - val_loss: 0.0984 - val_accuracy: 0.9705
#
# Number of neurons in the hidden layer: 128
# Epoch 1/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2623 - accuracy: 0.9237 - val_loss: 0.1450 - val_accuracy: 0.9581
# Epoch 2/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1139 - accuracy: 0.9668 - val_loss: 0.1004 - val_accuracy: 0.9687
# Epoch 3/5
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.0791 - accuracy: 0.9762 - val_loss: 0.0879 - val_accuracy: 0.9723
# Epoch 4/5
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0594 - accuracy: 0.9826 - val_loss: 0.0781 - val_accuracy: 0.9751
# Epoch 5/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0466 - accuracy: 0.9857 - val_loss: 0.0756 - val_accuracy: 0.9764
#
# Number of neurons in the hidden layer: 256
# Epoch 1/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2239 - accuracy: 0.9344 - val_loss: 0.1168 - val_accuracy: 0.9649
# Epoch 2/5
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0916 - accuracy: 0.9725 - val_loss: 0.0808 - val_accuracy: 0.9760
# Epoch 3/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0594 - accuracy: 0.9819 - val_loss: 0.0731 - val_accuracy: 0.9782
# Epoch 4/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0436 - accuracy: 0.9863 - val_loss: 0.0723 - val_accuracy: 0.9776
# Epoch 5/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0329 - accuracy: 0.9896 - val_loss: 0.0711 - val_accuracy: 0.9792
#
# Experiment 3: Use a different activation function
#
# Activation function: relu
# Epoch 1/5
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2614 - accuracy: 0.9256 - val_loss: 0.1364 - val_accuracy: 0.9582
# Epoch 2/5
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.1148 - accuracy: 0.9663 - val_loss: 0.0985 - val_accuracy: 0.9700
# Epoch 3/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0784 - accuracy: 0.9764 - val_loss: 0.0878 - val_accuracy: 0.9737
# Epoch 4/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0584 - accuracy: 0.9824 - val_loss: 0.0828 - val_accuracy: 0.9747
# Epoch 5/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0450 - accuracy: 0.9858 - val_loss: 0.0859 - val_accuracy: 0.9732
#
# Activation function: tanh
# Epoch 1/5
# 1875/1875 [==============================] - 11s 5ms/step - loss: 0.2892 - accuracy: 0.9164 - val_loss: 0.1781 - val_accuracy: 0.9479
# Epoch 2/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1395 - accuracy: 0.9590 - val_loss: 0.1179 - val_accuracy: 0.9659
# Epoch 3/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0954 - accuracy: 0.9718 - val_loss: 0.1028 - val_accuracy: 0.9706
# Epoch 4/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0697 - accuracy: 0.9800 - val_loss: 0.0862 - val_accuracy: 0.9740
# Epoch 5/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0528 - accuracy: 0.9849 - val_loss: 0.0850 - val_accuracy: 0.9735
#
# Activation function: sigmoid
# Epoch 1/5
# 1875/1875 [==============================] - 13s 6ms/step - loss: 0.3949 - accuracy: 0.8964 - val_loss: 0.2285 - val_accuracy: 0.9312
# Epoch 2/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1951 - accuracy: 0.9439 - val_loss: 0.1591 - val_accuracy: 0.9522
# Epoch 3/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1428 - accuracy: 0.9584 - val_loss: 0.1305 - val_accuracy: 0.9614
# Epoch 4/5
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.1109 - accuracy: 0.9678 - val_loss: 0.1119 - val_accuracy: 0.9672
# Epoch 5/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0881 - accuracy: 0.9750 - val_loss: 0.0955 - val_accuracy: 0.9712
